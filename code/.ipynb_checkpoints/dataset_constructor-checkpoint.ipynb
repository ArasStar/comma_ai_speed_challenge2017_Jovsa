# %%
#hooooop change212112

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import csv
import skvideo.io
from tqdm import tqdm
# %matplotlib inline

# %%
# !which python
# Out:
# /home/aras/Desktop/commaAI/jovsa_venv/bin/python

# %%
os.path.exists("/home/aras/Desktop/commaAI/speed_challenge_2017/data/train.mp4")
# Out:
# True

# %%
# constantshttp://localhost:8888/tree/speed_challenge_2017/data
DATA_PATH = '/home/aras/Desktop/commaAI/speed_challenge_2017/data'
TRAIN_VIDEO = os.path.join(DATA_PATH, 'train.mp4')
TEST_VIDEO = os.path.join(DATA_PATH, 'test.mp4')
CLEAN_DATA_PATH = '/home/aras/Desktop/commaAI/speed_challenge_2017/clean_data'
CLEAN_IMGS_TRAIN = os.path.join(CLEAN_DATA_PATH, 'train_imgs')
CLEAN_IMGS_TEST = os.path.join(CLEAN_DATA_PATH, 'test_imgs')

train_frames = 20400
test_frames = 10798

# %% [markdown]
# ## Dataset construction

# %%
train_y = list(pd.read_csv(os.path.join(DATA_PATH, 'train.txt'), header=None, squeeze=True))
assert(len(train_y)==train_frames)

# %%
def dataset_constructor(video_loc, img_folder, dataset_type):
    meta_dict = {}

    tqdm.write('reading in video file...')
    cap = skvideo.io.FFmpegReader(video_loc)
    tot_frames = cap.getShape()[0]
    cap.close()
    cap = skvideo.io.vreader(video_loc)
     
    tqdm.write('constructing dataset...')
    for idx, frame in enumerate(tqdm(cap,total=tot_frames)):    
        img_path = os.path.join(img_folder, str(idx)+'.jpg')
        frame_speed = float('NaN') if dataset_type == 'test' else train_y[idx]
        meta_dict[idx] = [img_path, idx, frame_speed]
        skvideo.io.vwrite(img_path, frame)
    meta_df = pd.DataFrame.from_dict(meta_dict, orient='index')
    meta_df.columns = ['image_path', 'image_index', 'speed']
    
    tqdm.write('writing meta to csv')
    meta_df.to_csv(os.path.join(CLEAN_DATA_PATH, dataset_type+'_meta.csv'), index=False)
    
    return "done dataset_constructor"

# %%
# train data
dataset_constructor(TRAIN_VIDEO, CLEAN_IMGS_TRAIN, 'train')
# Out:
#   0%|          | 0/20400 [00:00<?, ?it/s]
# reading in video file...
# constructing dataset...
# 100%|██████████| 20400/20400 [15:36<00:00, 21.78it/s]
# writing meta to csv
# 'done dataset_constructor'

# %%
# test data
dataset_constructor(TEST_VIDEO, CLEAN_IMGS_TEST, 'test')
# Out:
#   0%|          | 0/10798 [00:00<?, ?it/s]
# reading in video file...
# constructing dataset...
# 100%|██████████| 10798/10798 [08:14<00:00, 21.84it/s]
# writing meta to csv
# 'done dataset_constructor'

# %% [markdown]
# ## Dataset verification

# %% [markdown]
# ### train

# %%
train_meta = pd.read_csv(os.path.join(CLEAN_DATA_PATH, 'train_meta.csv'))
assert(train_meta.shape[0] == train_frames)
assert(train_meta.shape[1] == 3)

# %%
train_meta.head()
# Out:
#                                           image_path  image_index      speed
# 0  /home/aras/Desktop/commaAI/speed_challenge_201...            0  28.105569
# 1  /home/aras/Desktop/commaAI/speed_challenge_201...            1  28.105569
# 2  /home/aras/Desktop/commaAI/speed_challenge_201...            2  28.106527
# 3  /home/aras/Desktop/commaAI/speed_challenge_201...            3  28.130404
# 4  /home/aras/Desktop/commaAI/speed_challenge_201...            4  28.109243

# %%
for i in range(10):
    print('speed:',train_meta['speed'][i] )
    img=mpimg.imread(train_meta['image_path'][i])
    print('shape:', img.shape)
    plt.imshow(img)
    plt.show()
# Out:
# speed: 28.105569
# shape: (480, 640, 3)
# speed: 28.105569
# shape: (480, 640, 3)
# speed: 28.106527
# shape: (480, 640, 3)
# speed: 28.130404
# shape: (480, 640, 3)
# speed: 28.109243
# shape: (480, 640, 3)
# speed: 28.088572
# shape: (480, 640, 3)
# speed: 28.034211
# shape: (480, 640, 3)
# speed: 28.018491
# shape: (480, 640, 3)
# speed: 27.986624
# shape: (480, 640, 3)
# speed: 28.016352
# shape: (480, 640, 3)

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.plot(train_meta['speed'])
plt.xlabel('image_index (or time since start)')
plt.ylabel('speed')
plt.title('Speed vs time')
plt.show()

# %% [markdown]
# ### test

# %%
test_meta = pd.read_csv(os.path.join(CLEAN_DATA_PATH, 'test_meta.csv'))
assert(test_meta.shape[0] == test_frames)
assert(test_meta.shape[1] == 3)

# %%
test_meta.head()
# Out:
#                                           image_path  image_index  speed
# 0  /home/aras/Desktop/commaAI/speed_challenge_201...            0    NaN
# 1  /home/aras/Desktop/commaAI/speed_challenge_201...            1    NaN
# 2  /home/aras/Desktop/commaAI/speed_challenge_201...            2    NaN
# 3  /home/aras/Desktop/commaAI/speed_challenge_201...            3    NaN
# 4  /home/aras/Desktop/commaAI/speed_challenge_201...            4    NaN

# %%
for i in range(10):
    print('speed:',test_meta['speed'][i] )
    img=mpimg.imread(test_meta['image_path'][i])
    print('shape:', img.shape)
    plt.imshow(img)
    plt.show()
# Out:
# speed: nan
# shape: (480, 640, 3)
# speed: nan
# shape: (480, 640, 3)
# speed: nan
# shape: (480, 640, 3)
# speed: nan
# shape: (480, 640, 3)
# speed: nan
# shape: (480, 640, 3)
# speed: nan
# shape: (480, 640, 3)
# speed: nan
# shape: (480, 640, 3)
# speed: nan
# shape: (480, 640, 3)
# speed: nan
# shape: (480, 640, 3)
# speed: nan
# shape: (480, 640, 3)
